# %%
# !pip install torch torchvision transformers requests
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.17.1+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 25.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 39.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 49.0 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 583.1 kB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.6 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 9.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 6.1 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 3.9 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105

# %%
from transformers import BeitForImageClassification, BeitConfig, AdamW
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from torch.cuda.amp import GradScaler, autocast

# Path to your training data
train_data_path = '/content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train'

# Setup data transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Load the dataset
train_dataset = datasets.ImageFolder(root=train_data_path, transform=transform)

# Setup the data loader with a reduced batch size
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Initialize BEiT model
num_labels = len(train_dataset.classes)
config = BeitConfig.from_pretrained('microsoft/beit-base-patch16-224', num_labels=num_labels)
model = BeitForImageClassification.from_pretrained(
    'microsoft/beit-base-patch16-224',
    config=config,
    ignore_mismatched_sizes=True
)

# Prepare the model for training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
model.train()

# Setup optimizer and gradient scaler for mixed precision training
optimizer = AdamW(model.parameters(), lr=5e-5)
scaler = GradScaler()

# Define the number of steps for gradient accumulation
accumulation_steps = 4

# Calculate total number of batches
total_batches = len(train_loader)

# Training loop with mixed precision and gradient accumulation
for epoch in range(1):  # Adjust the number of epochs based on your needs
    model.train()
    optimizer.zero_grad()

    for step, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)

        with autocast():  # Mixed precision
            outputs = model(images, labels=labels)
            loss = outputs.loss / accumulation_steps  # Scale the loss for gradient accumulation

        scaler.scale(loss).backward()  # Scale the loss and backprop

        # Perform optimization step every `accumulation_steps`
        if (step + 1) % accumulation_steps == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        if step % accumulation_steps == 0:
            print(f"Epoch {epoch}, Step {step}/{total_batches}, Loss: {loss.item()}")

        # Calculate percentage of completion
        percent_complete = (step + 1) * batch_size / len(train_dataset) * 100
        print(f"Epoch {epoch}, Step {step}/{total_batches}, Percentage Complete: {percent_complete:.2f}%")

        # Clear unused memory
        torch.cuda.empty_cache()

# Save the fine-tuned model
model.save_pretrained('/content/drive/MyDrive/Project_IR/fine_tuned_model')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of BeitForImageClassification were not initialized from the model checkpoint at microsoft/beit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([24, 768]) in the model instantiated
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([24]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/cuda/amp/grad_scaler.py:126: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/amp/autocast_mode.py:250: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Epoch 0, Step 0/230, Loss: 0.8230054378509521
# Epoch 0, Step 0/230, Percentage Complete: 0.44%
# Epoch 0, Step 1/230, Percentage Complete: 0.87%
# Epoch 0, Step 2/230, Percentage Complete: 1.31%
# Epoch 0, Step 3/230, Percentage Complete: 1.74%
# Epoch 0, Step 4/230, Loss: 0.8240101933479309
# Epoch 0, Step 4/230, Percentage Complete: 2.18%
# Epoch 0, Step 5/230, Percentage Complete: 2.62%
# Epoch 0, Step 6/230, Percentage Complete: 3.05%
# Epoch 0, Step 7/230, Percentage Complete: 3.49%
# Epoch 0, Step 8/230, Loss: 0.8207409977912903
# Epoch 0, Step 8/230, Percentage Complete: 3.92%
# Epoch 0, Step 9/230, Percentage Complete: 4.36%
# Epoch 0, Step 10/230, Percentage Complete: 4.80%
# Epoch 0, Step 11/230, Percentage Complete: 5.23%
# Epoch 0, Step 12/230, Loss: 0.7419025897979736
# Epoch 0, Step 12/230, Percentage Complete: 5.67%
# Epoch 0, Step 13/230, Percentage Complete: 6.11%
# Epoch 0, Step 14/230, Percentage Complete: 6.54%
# Epoch 0, Step 15/230, Percentage Complete: 6.98%
# Epoch 0, Step 16/230, Loss: 0.7340998649597168
# Epoch 0, Step 16/230, Percentage Complete: 7.41%
# Epoch 0, Step 17/230, Percentage Complete: 7.85%
# Epoch 0, Step 18/230, Percentage Complete: 8.29%
# Epoch 0, Step 19/230, Percentage Complete: 8.72%
# Epoch 0, Step 20/230, Loss: 0.7691364884376526
# Epoch 0, Step 20/230, Percentage Complete: 9.16%
# Epoch 0, Step 21/230, Percentage Complete: 9.59%
# Epoch 0, Step 22/230, Percentage Complete: 10.03%
# Epoch 0, Step 23/230, Percentage Complete: 10.47%
# Epoch 0, Step 24/230, Loss: 0.6939876079559326
# Epoch 0, Step 24/230, Percentage Complete: 10.90%
# Epoch 0, Step 25/230, Percentage Complete: 11.34%
# Epoch 0, Step 26/230, Percentage Complete: 11.77%
# Epoch 0, Step 27/230, Percentage Complete: 12.21%
# Epoch 0, Step 28/230, Loss: 0.6894715428352356
# Epoch 0, Step 28/230, Percentage Complete: 12.65%
# Epoch 0, Step 29/230, Percentage Complete: 13.08%
# Epoch 0, Step 30/230, Percentage Complete: 13.52%
# Epoch 0, Step 31/230, Percentage Complete: 13.95%
# Epoch 0, Step 32/230, Loss: 0.6577796936035156
# Epoch 0, Step 32/230, Percentage Complete: 14.39%
# Epoch 0, Step 33/230, Percentage Complete: 14.83%
# Epoch 0, Step 34/230, Percentage Complete: 15.26%
# Epoch 0, Step 35/230, Percentage Complete: 15.70%
# Epoch 0, Step 36/230, Loss: 0.679114818572998
# Epoch 0, Step 36/230, Percentage Complete: 16.14%
# Epoch 0, Step 37/230, Percentage Complete: 16.57%
# Epoch 0, Step 38/230, Percentage Complete: 17.01%
# Epoch 0, Step 39/230, Percentage Complete: 17.44%
# Epoch 0, Step 40/230, Loss: 0.6827260255813599
# Epoch 0, Step 40/230, Percentage Complete: 17.88%
# Epoch 0, Step 41/230, Percentage Complete: 18.32%
# Epoch 0, Step 42/230, Percentage Complete: 18.75%
# Epoch 0, Step 43/230, Percentage Complete: 19.19%
# Epoch 0, Step 44/230, Loss: 0.6988170742988586
# Epoch 0, Step 44/230, Percentage Complete: 19.62%
# Epoch 0, Step 45/230, Percentage Complete: 20.06%
# Epoch 0, Step 46/230, Percentage Complete: 20.50%
# Epoch 0, Step 47/230, Percentage Complete: 20.93%
# Epoch 0, Step 48/230, Loss: 0.6882622838020325
# Epoch 0, Step 48/230, Percentage Complete: 21.37%
# Epoch 0, Step 49/230, Percentage Complete: 21.80%
# Epoch 0, Step 50/230, Percentage Complete: 22.24%
# Epoch 0, Step 51/230, Percentage Complete: 22.68%
# Epoch 0, Step 52/230, Loss: 0.6456046104431152
# Epoch 0, Step 52/230, Percentage Complete: 23.11%
# Epoch 0, Step 53/230, Percentage Complete: 23.55%
# Epoch 0, Step 54/230, Percentage Complete: 23.98%
# Epoch 0, Step 55/230, Percentage Complete: 24.42%
# Epoch 0, Step 56/230, Loss: 0.5425229668617249
# Epoch 0, Step 56/230, Percentage Complete: 24.86%
# Epoch 0, Step 57/230, Percentage Complete: 25.29%
# Epoch 0, Step 58/230, Percentage Complete: 25.73%
# Epoch 0, Step 59/230, Percentage Complete: 26.17%
# Epoch 0, Step 60/230, Loss: 0.564399003982544
# Epoch 0, Step 60/230, Percentage Complete: 26.60%
# Epoch 0, Step 61/230, Percentage Complete: 27.04%
# Epoch 0, Step 62/230, Percentage Complete: 27.47%
# Epoch 0, Step 63/230, Percentage Complete: 27.91%
# Epoch 0, Step 64/230, Loss: 0.6576498746871948
# Epoch 0, Step 64/230, Percentage Complete: 28.35%
# Epoch 0, Step 65/230, Percentage Complete: 28.78%
# Epoch 0, Step 66/230, Percentage Complete: 29.22%
# Epoch 0, Step 67/230, Percentage Complete: 29.65%
# Epoch 0, Step 68/230, Loss: 0.5684822797775269
# Epoch 0, Step 68/230, Percentage Complete: 30.09%
# Epoch 0, Step 69/230, Percentage Complete: 30.53%
# Epoch 0, Step 70/230, Percentage Complete: 30.96%
# Epoch 0, Step 71/230, Percentage Complete: 31.40%
# Epoch 0, Step 72/230, Loss: 0.6350451707839966
# Epoch 0, Step 72/230, Percentage Complete: 31.83%
# Epoch 0, Step 73/230, Percentage Complete: 32.27%
# Epoch 0, Step 74/230, Percentage Complete: 32.71%
# Epoch 0, Step 75/230, Percentage Complete: 33.14%
# Epoch 0, Step 76/230, Loss: 0.49456217885017395
# Epoch 0, Step 76/230, Percentage Complete: 33.58%
# Epoch 0, Step 77/230, Percentage Complete: 34.01%
# Epoch 0, Step 78/230, Percentage Complete: 34.45%
# Epoch 0, Step 79/230, Percentage Complete: 34.89%
# Epoch 0, Step 80/230, Loss: 0.3416559398174286
# Epoch 0, Step 80/230, Percentage Complete: 35.32%
# Epoch 0, Step 81/230, Percentage Complete: 35.76%
# Epoch 0, Step 82/230, Percentage Complete: 36.20%
# Epoch 0, Step 83/230, Percentage Complete: 36.63%
# Epoch 0, Step 84/230, Loss: 0.6691598296165466
# Epoch 0, Step 84/230, Percentage Complete: 37.07%
# Epoch 0, Step 85/230, Percentage Complete: 37.50%
# Epoch 0, Step 86/230, Percentage Complete: 37.94%
# Epoch 0, Step 87/230, Percentage Complete: 38.38%
# Epoch 0, Step 88/230, Loss: 0.5062589645385742
# Epoch 0, Step 88/230, Percentage Complete: 38.81%
# Epoch 0, Step 89/230, Percentage Complete: 39.25%
# Epoch 0, Step 90/230, Percentage Complete: 39.68%
# Epoch 0, Step 91/230, Percentage Complete: 40.12%
# Epoch 0, Step 92/230, Loss: 0.49108973145484924
# Epoch 0, Step 92/230, Percentage Complete: 40.56%
# Epoch 0, Step 93/230, Percentage Complete: 40.99%
# Epoch 0, Step 94/230, Percentage Complete: 41.43%
# Epoch 0, Step 95/230, Percentage Complete: 41.86%
# Epoch 0, Step 96/230, Loss: 0.4656771719455719
# Epoch 0, Step 96/230, Percentage Complete: 42.30%
# Epoch 0, Step 97/230, Percentage Complete: 42.74%
# Epoch 0, Step 98/230, Percentage Complete: 43.17%
# Epoch 0, Step 99/230, Percentage Complete: 43.61%
# Epoch 0, Step 100/230, Loss: 0.3818703591823578
# Epoch 0, Step 100/230, Percentage Complete: 44.04%
# Epoch 0, Step 101/230, Percentage Complete: 44.48%
# Epoch 0, Step 102/230, Percentage Complete: 44.92%
# Epoch 0, Step 103/230, Percentage Complete: 45.35%
# Epoch 0, Step 104/230, Loss: 0.31599724292755127
# Epoch 0, Step 104/230, Percentage Complete: 45.79%
# Epoch 0, Step 105/230, Percentage Complete: 46.23%
# Epoch 0, Step 106/230, Percentage Complete: 46.66%
# Epoch 0, Step 107/230, Percentage Complete: 47.10%
# Epoch 0, Step 108/230, Loss: 0.32476529479026794
# Epoch 0, Step 108/230, Percentage Complete: 47.53%
# Epoch 0, Step 109/230, Percentage Complete: 47.97%
# Epoch 0, Step 110/230, Percentage Complete: 48.41%
# Epoch 0, Step 111/230, Percentage Complete: 48.84%
# Epoch 0, Step 112/230, Loss: 0.3071015775203705
# Epoch 0, Step 112/230, Percentage Complete: 49.28%
# Epoch 0, Step 113/230, Percentage Complete: 49.71%
# Epoch 0, Step 114/230, Percentage Complete: 50.15%
# Epoch 0, Step 115/230, Percentage Complete: 50.59%
# Epoch 0, Step 116/230, Loss: 0.3690546154975891
# Epoch 0, Step 116/230, Percentage Complete: 51.02%
# Epoch 0, Step 117/230, Percentage Complete: 51.46%
# Epoch 0, Step 118/230, Percentage Complete: 51.89%
# Epoch 0, Step 119/230, Percentage Complete: 52.33%
# Epoch 0, Step 120/230, Loss: 0.25381937623023987
# Epoch 0, Step 120/230, Percentage Complete: 52.77%
# Epoch 0, Step 121/230, Percentage Complete: 53.20%
# Epoch 0, Step 122/230, Percentage Complete: 53.64%
# Epoch 0, Step 123/230, Percentage Complete: 54.07%
# Epoch 0, Step 124/230, Loss: 0.3258313238620758
# Epoch 0, Step 124/230, Percentage Complete: 54.51%
# Epoch 0, Step 125/230, Percentage Complete: 54.95%
# Epoch 0, Step 126/230, Percentage Complete: 55.38%
# Epoch 0, Step 127/230, Percentage Complete: 55.82%
# Epoch 0, Step 128/230, Loss: 0.3729937672615051
# Epoch 0, Step 128/230, Percentage Complete: 56.26%
# Epoch 0, Step 129/230, Percentage Complete: 56.69%
# Epoch 0, Step 130/230, Percentage Complete: 57.13%
# Epoch 0, Step 131/230, Percentage Complete: 57.56%
# Epoch 0, Step 132/230, Loss: 0.4208739399909973
# Epoch 0, Step 132/230, Percentage Complete: 58.00%
# Epoch 0, Step 133/230, Percentage Complete: 58.44%
# Epoch 0, Step 134/230, Percentage Complete: 58.87%
# Epoch 0, Step 135/230, Percentage Complete: 59.31%
# Epoch 0, Step 136/230, Loss: 0.2787743806838989
# Epoch 0, Step 136/230, Percentage Complete: 59.74%
# Epoch 0, Step 137/230, Percentage Complete: 60.18%
# Epoch 0, Step 138/230, Percentage Complete: 60.62%
# Epoch 0, Step 139/230, Percentage Complete: 61.05%
# Epoch 0, Step 140/230, Loss: 0.31449419260025024
# Epoch 0, Step 140/230, Percentage Complete: 61.49%
# Epoch 0, Step 141/230, Percentage Complete: 61.92%
# Epoch 0, Step 142/230, Percentage Complete: 62.36%
# Epoch 0, Step 143/230, Percentage Complete: 62.80%
# Epoch 0, Step 144/230, Loss: 0.17914335429668427
# Epoch 0, Step 144/230, Percentage Complete: 63.23%
# Epoch 0, Step 145/230, Percentage Complete: 63.67%
# Epoch 0, Step 146/230, Percentage Complete: 64.10%
# Epoch 0, Step 147/230, Percentage Complete: 64.54%
# Epoch 0, Step 148/230, Loss: 0.3539119362831116
# Epoch 0, Step 148/230, Percentage Complete: 64.98%
# Epoch 0, Step 149/230, Percentage Complete: 65.41%
# Epoch 0, Step 150/230, Percentage Complete: 65.85%
# Epoch 0, Step 151/230, Percentage Complete: 66.29%
# Epoch 0, Step 152/230, Loss: 0.19993863999843597
# Epoch 0, Step 152/230, Percentage Complete: 66.72%
# Epoch 0, Step 153/230, Percentage Complete: 67.16%
# Epoch 0, Step 154/230, Percentage Complete: 67.59%
# Epoch 0, Step 155/230, Percentage Complete: 68.03%
# Epoch 0, Step 156/230, Loss: 0.1584162712097168
# Epoch 0, Step 156/230, Percentage Complete: 68.47%
# Epoch 0, Step 157/230, Percentage Complete: 68.90%
# Epoch 0, Step 158/230, Percentage Complete: 69.34%
# Epoch 0, Step 159/230, Percentage Complete: 69.77%
# Epoch 0, Step 160/230, Loss: 0.2463948130607605
# Epoch 0, Step 160/230, Percentage Complete: 70.21%
# Epoch 0, Step 161/230, Percentage Complete: 70.65%
# Epoch 0, Step 162/230, Percentage Complete: 71.08%
# Epoch 0, Step 163/230, Percentage Complete: 71.52%
# Epoch 0, Step 164/230, Loss: 0.21979373693466187
# Epoch 0, Step 164/230, Percentage Complete: 71.95%
# Epoch 0, Step 165/230, Percentage Complete: 72.39%
# Epoch 0, Step 166/230, Percentage Complete: 72.83%
# Epoch 0, Step 167/230, Percentage Complete: 73.26%
# Epoch 0, Step 168/230, Loss: 0.20871666073799133
# Epoch 0, Step 168/230, Percentage Complete: 73.70%
# Epoch 0, Step 169/230, Percentage Complete: 74.13%
# Epoch 0, Step 170/230, Percentage Complete: 74.57%
# Epoch 0, Step 171/230, Percentage Complete: 75.01%
# Epoch 0, Step 172/230, Loss: 0.20174925029277802
# Epoch 0, Step 172/230, Percentage Complete: 75.44%
# Epoch 0, Step 173/230, Percentage Complete: 75.88%
# Epoch 0, Step 174/230, Percentage Complete: 76.32%
# Epoch 0, Step 175/230, Percentage Complete: 76.75%
# Epoch 0, Step 176/230, Loss: 0.09980746358633041
# Epoch 0, Step 176/230, Percentage Complete: 77.19%
# Epoch 0, Step 177/230, Percentage Complete: 77.62%
# Epoch 0, Step 178/230, Percentage Complete: 78.06%
# Epoch 0, Step 179/230, Percentage Complete: 78.50%
# Epoch 0, Step 180/230, Loss: 0.16652917861938477
# Epoch 0, Step 180/230, Percentage Complete: 78.93%
# Epoch 0, Step 181/230, Percentage Complete: 79.37%
# Epoch 0, Step 182/230, Percentage Complete: 79.80%
# Epoch 0, Step 183/230, Percentage Complete: 80.24%
# Epoch 0, Step 184/230, Loss: 0.15149253606796265
# Epoch 0, Step 184/230, Percentage Complete: 80.68%
# Epoch 0, Step 185/230, Percentage Complete: 81.11%
# Epoch 0, Step 186/230, Percentage Complete: 81.55%
# Epoch 0, Step 187/230, Percentage Complete: 81.98%
# Epoch 0, Step 188/230, Loss: 0.1855723112821579
# Epoch 0, Step 188/230, Percentage Complete: 82.42%
# Epoch 0, Step 189/230, Percentage Complete: 82.86%
# Epoch 0, Step 190/230, Percentage Complete: 83.29%
# Epoch 0, Step 191/230, Percentage Complete: 83.73%
# Epoch 0, Step 192/230, Loss: 0.16022980213165283
# Epoch 0, Step 192/230, Percentage Complete: 84.16%
# Epoch 0, Step 193/230, Percentage Complete: 84.60%
# Epoch 0, Step 194/230, Percentage Complete: 85.04%
# Epoch 0, Step 195/230, Percentage Complete: 85.47%
# Epoch 0, Step 196/230, Loss: 0.07644876092672348
# Epoch 0, Step 196/230, Percentage Complete: 85.91%
# Epoch 0, Step 197/230, Percentage Complete: 86.35%
# Epoch 0, Step 198/230, Percentage Complete: 86.78%
# Epoch 0, Step 199/230, Percentage Complete: 87.22%
# Epoch 0, Step 200/230, Loss: 0.10816404968500137
# Epoch 0, Step 200/230, Percentage Complete: 87.65%
# Epoch 0, Step 201/230, Percentage Complete: 88.09%
# Epoch 0, Step 202/230, Percentage Complete: 88.53%
# Epoch 0, Step 203/230, Percentage Complete: 88.96%
# Epoch 0, Step 204/230, Loss: 0.14954927563667297
# Epoch 0, Step 204/230, Percentage Complete: 89.40%
# Epoch 0, Step 205/230, Percentage Complete: 89.83%
# Epoch 0, Step 206/230, Percentage Complete: 90.27%
# Epoch 0, Step 207/230, Percentage Complete: 90.71%
# Epoch 0, Step 208/230, Loss: 0.1561138927936554
# Epoch 0, Step 208/230, Percentage Complete: 91.14%
# Epoch 0, Step 209/230, Percentage Complete: 91.58%
# Epoch 0, Step 210/230, Percentage Complete: 92.01%
# Epoch 0, Step 211/230, Percentage Complete: 92.45%
# Epoch 0, Step 212/230, Loss: 0.12342695891857147
# Epoch 0, Step 212/230, Percentage Complete: 92.89%
# Epoch 0, Step 213/230, Percentage Complete: 93.32%
# Epoch 0, Step 214/230, Percentage Complete: 93.76%
# Epoch 0, Step 215/230, Percentage Complete: 94.19%
# Epoch 0, Step 216/230, Loss: 0.08443275094032288
# Epoch 0, Step 216/230, Percentage Complete: 94.63%
# Epoch 0, Step 217/230, Percentage Complete: 95.07%
# Epoch 0, Step 218/230, Percentage Complete: 95.50%
# Epoch 0, Step 219/230, Percentage Complete: 95.94%
# Epoch 0, Step 220/230, Loss: 0.058721594512462616
# Epoch 0, Step 220/230, Percentage Complete: 96.38%
# Epoch 0, Step 221/230, Percentage Complete: 96.81%
# Epoch 0, Step 222/230, Percentage Complete: 97.25%
# Epoch 0, Step 223/230, Percentage Complete: 97.68%
# Epoch 0, Step 224/230, Loss: 0.11621113121509552
# Epoch 0, Step 224/230, Percentage Complete: 98.12%
# Epoch 0, Step 225/230, Percentage Complete: 98.56%
# Epoch 0, Step 226/230, Percentage Complete: 98.99%
# Epoch 0, Step 227/230, Percentage Complete: 99.43%
# Epoch 0, Step 228/230, Loss: 0.11248898506164551
# Epoch 0, Step 228/230, Percentage Complete: 99.86%
# Epoch 0, Step 229/230, Percentage Complete: 100.30%

# %%
from transformers import BeitForImageClassification, BeitFeatureExtractor
from PIL import Image
import torch
from torchvision.transforms import Compose, Resize, ToTensor, Normalize
import requests
from io import BytesIO

# Class names mapping
class_names = [
    "Ajanta Caves", "Charar-E- Sharif", "Chhota Imambara", "Ellora Caves", "Fatehpur Sikiri",
    "Hawa Mahal", "Gateway of India", "Khajuraho", "Sun Temple Konark", "Alai Darwaza",
    "Alai Minar", "Basilica of Bom Jesus", "Charminar", "Golden Temple", "Iron Pillar",
    "Jamali Kamali Tomb", "Lotus Temple", "Mysore Palace", "Qutub Minar", "Taj Mahal",
    "Tanjavur Temple", "Victoria Memorial"
]

# Function to predict the class of an image from a URL
def predict_image_class_from_url(image_url):
    # Load the fine-tuned model and the feature extractor
    model_path = '/content/drive/MyDrive/Project_IR/fine_tuned_model'
    model = BeitForImageClassification.from_pretrained(model_path)
    feature_extractor = BeitFeatureExtractor.from_pretrained('microsoft/beit-base-patch16-224')

    # Ensure model is in evaluation mode
    model.eval()

    # Device configuration
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    # Use requests to download the image
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content)).convert("RGB")

    # Preprocess the image
    transform = Compose([
        Resize((224, 224)),
        ToTensor(),
        Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    image = transform(image).unsqueeze(0)  # Add batch dimension

    # Move image to the same device as the model
    image = image.to(device)

    # Perform inference
    with torch.no_grad():
        outputs = model(image)
        preds = outputs.logits.softmax(dim=-1)
        predicted_index = preds.argmax(1).item()

    # Translate the predicted index to class name using the mapping
    predicted_class = class_names[predicted_index]
    return f"Predicted class for the image: {predicted_class}"

# Example usage
# Replace the URL with the actual URL of the image you want to classify
image_url = input("ENTER HTTPS LINK: ")
predicted_class = predict_image_class_from_url(image_url)
print(predicted_class)
# Out:
# ENTER HTTPS LINK: https://cdn.britannica.com/70/153470-050-F4594C27/Ajanta-Caves-Maharashtra-India.jpg
# Predicted class for the image: Ajanta Caves

# %%
from transformers import BeitForImageClassification, BeitFeatureExtractor
from PIL import Image
import torch
from torchvision.transforms import Compose, Resize, ToTensor, Normalize
import requests
from io import BytesIO

# Class names mapping
class_names = [
    "Ajanta Caves", "Charar-E- Sharif", "Chhota Imambara", "Ellora Caves", "Fatehpur Sikiri",
    "Hawa Mahal", "Gateway of India", "Khajuraho", "Sun Temple Konark", "Alai Darwaza",
    "Alai Minar", "Basilica of Bom Jesus", "Charminar", "Golden Temple", "Iron Pillar",
    "Jamali Kamali Tomb", "Lotus Temple", "Mysore Palace", "Qutub Minar", "Taj Mahal",
    "Tanjavur Temple", "Victoria Memorial"
]

# Function to predict the class of an image given a path or URL
def predict_image_class(image_input):
    # Load the fine-tuned model and the feature extractor
    model_path = '/content/drive/MyDrive/Project_IR/fine_tuned_model'
    model = BeitForImageClassification.from_pretrained(model_path)
    feature_extractor = BeitFeatureExtractor.from_pretrained('microsoft/beit-base-patch16-224')

    # Ensure model is in evaluation mode
    model.eval()

    # Device configuration
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    # Check if the input is a URL
    if image_input.startswith('http'):
        response = requests.get(image_input)
        image = Image.open(BytesIO(response.content)).convert("RGB")
    else:
        # Assume it's a file path
        image = Image.open(image_input).convert("RGB")

    # Preprocess the image
    transform = Compose([
        Resize((224, 224)),
        ToTensor(),
        Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    image = transform(image).unsqueeze(0)  # Add batch dimension

    # Move image to the same device as the model
    image = image.to(device)

    # Perform inference
    with torch.no_grad():
        outputs = model(image)
        preds = outputs.logits.softmax(dim=-1)
        predicted_index = preds.argmax(1).item()

    # Ensure the predicted index is within the range of class names
    if predicted_index < len(class_names):
        predicted_class = class_names[predicted_index]
    else:
        predicted_class = "Unknown Class"

    return f"Predicted class for the image: {predicted_class}"

# Example usage with a path or URL
image_input = '/content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/test/Ellora Caves/12.jpg'
# For URL, uncomment and use something like:
# image_input = 'https://example.com/path/to/image.jpg'

predicted_class = predict_image_class(image_input)
print(predicted_class)
# Out:
# Predicted class for the image: Ellora Caves

# %%
from torchvision import datasets
import pickle

# Load your dataset
train_data_path = '/content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train'
dataset = datasets.ImageFolder(root=train_data_path)

# Save the image paths
dataset_image_paths = [item[0] for item in dataset.imgs]
with open('/content/drive/MyDrive/Project_IR/Monuments_dataset_image_paths.pkl', 'wb') as f:
    pickle.dump(dataset_image_paths, f)

print("Image paths saved.")
# Out:
# Image paths saved.

# %%
import os
from PIL import Image
import numpy as np
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.preprocessing import image as keras_image
from tensorflow.keras.models import Model
import pickle

# Initialize the InceptionV3 model
base_model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')
model = Model(inputs=base_model.input, outputs=base_model.output)

def preprocess_image(img_path):
    """Load and preprocess an image."""
    img = keras_image.load_img(img_path, target_size=(299, 299))
    img_array = keras_image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return preprocess_input(img_array)

def extract_features(image_path, model):
    """Extract features for a single image."""
    img_array = preprocess_image(image_path)
    features = model.predict(img_array)
    return features.flatten()

def process_images_and_save(dataset_path, output_file):
    """Process all images in the dataset and save their features and paths."""
    image_features = []
    image_paths = []

    # Calculate total number of images for progress updates
    total_images = sum([len(files) for r, _, files in os.walk(dataset_path)])
    processed_images = 0

    # Walk through the directory, preprocess images, and extract features
    for root, _, files in os.walk(dataset_path):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg','.jfif')):
                image_path = os.path.join(root, file)
                try:
                    features = extract_features(image_path, model)
                    image_features.append(features)
                    image_paths.append(image_path)
                except Exception as e:
                    print(f"Error processing {image_path}: {e}")

                processed_images += 1
                print(f"Progress: {processed_images}/{total_images} images processed ({(processed_images/total_images)*100:.2f}%)")

    # Save the features and paths to a .pkl file
    with open(output_file, 'wb') as f:
        pickle.dump({'paths': image_paths, 'features': image_features}, f)
    print("All features extracted and saved.")

# Specify the dataset directory and the output file path
dataset_path = '/content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train'  # Update this path
output_file = '/content/drive/MyDrive/Project_IR/dataset_features_Monuments.pkl'  # Update this path

# Execute the processing and saving of image features
process_images_and_save(dataset_path, output_file)
# Out:
# Streaming output truncated to the last 5000 lines.
# Progress: 1243/3746 images processed (33.18%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 1244/3746 images processed (33.21%)
# 1/1 [==============================] - 0s 266ms/step
# Progress: 1245/3746 images processed (33.24%)
# 1/1 [==============================] - 0s 445ms/step
# Progress: 1246/3746 images processed (33.26%)
# 1/1 [==============================] - 0s 414ms/step
# Progress: 1247/3746 images processed (33.29%)
# 1/1 [==============================] - 0s 440ms/step
# Progress: 1248/3746 images processed (33.32%)
# 1/1 [==============================] - 0s 420ms/step
# Progress: 1249/3746 images processed (33.34%)
# 1/1 [==============================] - 0s 415ms/step
# Progress: 1250/3746 images processed (33.37%)
# 1/1 [==============================] - 0s 322ms/step
# Progress: 1251/3746 images processed (33.40%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1252/3746 images processed (33.42%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 1253/3746 images processed (33.45%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1254/3746 images processed (33.48%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1255/3746 images processed (33.50%)
# 1/1 [==============================] - 0s 261ms/step
# Progress: 1256/3746 images processed (33.53%)
# 1/1 [==============================] - 0s 268ms/step
# Progress: 1257/3746 images processed (33.56%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 1258/3746 images processed (33.58%)
# 1/1 [==============================] - 0s 272ms/step
# Progress: 1259/3746 images processed (33.61%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1260/3746 images processed (33.64%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1261/3746 images processed (33.66%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1262/3746 images processed (33.69%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1263/3746 images processed (33.72%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1264/3746 images processed (33.74%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 1265/3746 images processed (33.77%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 1266/3746 images processed (33.80%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 1267/3746 images processed (33.82%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1268/3746 images processed (33.85%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 1269/3746 images processed (33.88%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1270/3746 images processed (33.90%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1271/3746 images processed (33.93%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 1272/3746 images processed (33.96%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 1273/3746 images processed (33.98%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1274/3746 images processed (34.01%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 1275/3746 images processed (34.04%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 1276/3746 images processed (34.06%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 1277/3746 images processed (34.09%)
# 1/1 [==============================] - 0s 357ms/step
# Progress: 1278/3746 images processed (34.12%)
# 1/1 [==============================] - 0s 440ms/step
# Progress: 1279/3746 images processed (34.14%)
# 1/1 [==============================] - 0s 399ms/step
# Progress: 1280/3746 images processed (34.17%)
# 1/1 [==============================] - 0s 425ms/step
# Progress: 1281/3746 images processed (34.20%)
# 1/1 [==============================] - 0s 425ms/step
# Progress: 1282/3746 images processed (34.22%)
# 1/1 [==============================] - 0s 430ms/step
# Progress: 1283/3746 images processed (34.25%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1284/3746 images processed (34.28%)
# 1/1 [==============================] - 0s 289ms/step
# Progress: 1285/3746 images processed (34.30%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1286/3746 images processed (34.33%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 1287/3746 images processed (34.36%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1288/3746 images processed (34.38%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 1289/3746 images processed (34.41%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1290/3746 images processed (34.44%)
# 1/1 [==============================] - 0s 269ms/step
# Progress: 1291/3746 images processed (34.46%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 1292/3746 images processed (34.49%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 1293/3746 images processed (34.52%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1294/3746 images processed (34.54%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1295/3746 images processed (34.57%)
# 1/1 [==============================] - 0s 283ms/step
# Progress: 1296/3746 images processed (34.60%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 1297/3746 images processed (34.62%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 1298/3746 images processed (34.65%)
# 1/1 [==============================] - 0s 265ms/step
# Progress: 1299/3746 images processed (34.68%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1300/3746 images processed (34.70%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1301/3746 images processed (34.73%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1302/3746 images processed (34.76%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1303/3746 images processed (34.78%)
# 1/1 [==============================] - 0s 274ms/step
# Progress: 1304/3746 images processed (34.81%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 1305/3746 images processed (34.84%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1306/3746 images processed (34.86%)
# 1/1 [==============================] - 0s 267ms/step
# Progress: 1307/3746 images processed (34.89%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1308/3746 images processed (34.92%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 1309/3746 images processed (34.94%)
# 1/1 [==============================] - 0s 446ms/step
# Progress: 1310/3746 images processed (34.97%)
# 1/1 [==============================] - 0s 431ms/step
# Progress: 1311/3746 images processed (35.00%)
# 1/1 [==============================] - 0s 412ms/step
# Progress: 1312/3746 images processed (35.02%)
# 1/1 [==============================] - 0s 461ms/step
# Progress: 1313/3746 images processed (35.05%)
# 1/1 [==============================] - 0s 485ms/step
# Progress: 1314/3746 images processed (35.08%)
# 1/1 [==============================] - 0s 477ms/step
# Progress: 1315/3746 images processed (35.10%)
# 1/1 [==============================] - 1s 508ms/step
# Progress: 1316/3746 images processed (35.13%)
# 1/1 [==============================] - 0s 461ms/step
# Progress: 1317/3746 images processed (35.16%)
# 1/1 [==============================] - 0s 440ms/step
# Progress: 1318/3746 images processed (35.18%)
# 1/1 [==============================] - 0s 448ms/step
# Progress: 1319/3746 images processed (35.21%)
# 1/1 [==============================] - 0s 394ms/step
# Progress: 1320/3746 images processed (35.24%)
# 1/1 [==============================] - 0s 378ms/step
# Progress: 1321/3746 images processed (35.26%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1322/3746 images processed (35.29%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1323/3746 images processed (35.32%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1324/3746 images processed (35.34%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1325/3746 images processed (35.37%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1326/3746 images processed (35.40%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1327/3746 images processed (35.42%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1328/3746 images processed (35.45%)
# 1/1 [==============================] - 0s 275ms/step
# Progress: 1329/3746 images processed (35.48%)
# 1/1 [==============================] - 0s 264ms/step
# Progress: 1330/3746 images processed (35.50%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1331/3746 images processed (35.53%)
# 1/1 [==============================] - 0s 268ms/step
# Progress: 1332/3746 images processed (35.56%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 1333/3746 images processed (35.58%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1334/3746 images processed (35.61%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 1335/3746 images processed (35.64%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1336/3746 images processed (35.66%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1337/3746 images processed (35.69%)
# 1/1 [==============================] - 0s 265ms/step
# Progress: 1338/3746 images processed (35.72%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1339/3746 images processed (35.74%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1340/3746 images processed (35.77%)
# 1/1 [==============================] - 0s 284ms/step
# Progress: 1341/3746 images processed (35.80%)
# 1/1 [==============================] - 0s 431ms/step
# Progress: 1342/3746 images processed (35.82%)
# 1/1 [==============================] - 0s 403ms/step
# Progress: 1343/3746 images processed (35.85%)
# 1/1 [==============================] - 0s 421ms/step
# Progress: 1344/3746 images processed (35.88%)
# 1/1 [==============================] - 0s 458ms/step
# Progress: 1345/3746 images processed (35.90%)
# 1/1 [==============================] - 0s 444ms/step
# Progress: 1346/3746 images processed (35.93%)
# 1/1 [==============================] - 0s 396ms/step
# Progress: 1347/3746 images processed (35.96%)
# 1/1 [==============================] - 0s 261ms/step
# Progress: 1348/3746 images processed (35.99%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1349/3746 images processed (36.01%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1350/3746 images processed (36.04%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1351/3746 images processed (36.07%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1352/3746 images processed (36.09%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 1353/3746 images processed (36.12%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1354/3746 images processed (36.15%)
# 1/1 [==============================] - 0s 280ms/step
# Progress: 1355/3746 images processed (36.17%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 1356/3746 images processed (36.20%)
# 1/1 [==============================] - 0s 261ms/step
# Progress: 1357/3746 images processed (36.23%)
# 1/1 [==============================] - 0s 274ms/step
# Progress: 1358/3746 images processed (36.25%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1359/3746 images processed (36.28%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1360/3746 images processed (36.31%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1361/3746 images processed (36.33%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1362/3746 images processed (36.36%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1363/3746 images processed (36.39%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1364/3746 images processed (36.41%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1365/3746 images processed (36.44%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1366/3746 images processed (36.47%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 1367/3746 images processed (36.49%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1368/3746 images processed (36.52%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 1369/3746 images processed (36.55%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 1370/3746 images processed (36.57%)
# 1/1 [==============================] - 0s 282ms/step
# Progress: 1371/3746 images processed (36.60%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1372/3746 images processed (36.63%)
# 1/1 [==============================] - 0s 389ms/step
# Progress: 1373/3746 images processed (36.65%)
# 1/1 [==============================] - 1s 659ms/step
# Progress: 1374/3746 images processed (36.68%)
# 1/1 [==============================] - 0s 446ms/step
# Progress: 1375/3746 images processed (36.71%)
# 1/1 [==============================] - 0s 466ms/step
# Progress: 1376/3746 images processed (36.73%)
# 1/1 [==============================] - 0s 447ms/step
# Progress: 1377/3746 images processed (36.76%)
# 1/1 [==============================] - 0s 431ms/step
# Progress: 1378/3746 images processed (36.79%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1379/3746 images processed (36.81%)
# 1/1 [==============================] - 0s 269ms/step
# Progress: 1380/3746 images processed (36.84%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1381/3746 images processed (36.87%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 1382/3746 images processed (36.89%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1383/3746 images processed (36.92%)
# 1/1 [==============================] - 0s 265ms/step
# Progress: 1384/3746 images processed (36.95%)
# 1/1 [==============================] - 0s 268ms/step
# Progress: 1385/3746 images processed (36.97%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 1386/3746 images processed (37.00%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1387/3746 images processed (37.03%)
# 1/1 [==============================] - 0s 270ms/step
# Progress: 1388/3746 images processed (37.05%)
# 1/1 [==============================] - 0s 261ms/step
# Progress: 1389/3746 images processed (37.08%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 1390/3746 images processed (37.11%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1391/3746 images processed (37.13%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1392/3746 images processed (37.16%)
# 1/1 [==============================] - 0s 286ms/step
# Progress: 1393/3746 images processed (37.19%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1394/3746 images processed (37.21%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1395/3746 images processed (37.24%)
# 1/1 [==============================] - 0s 284ms/step
# Progress: 1396/3746 images processed (37.27%)
# 1/1 [==============================] - 0s 271ms/step
# Progress: 1397/3746 images processed (37.29%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 1398/3746 images processed (37.32%)
# 1/1 [==============================] - 0s 265ms/step
# Progress: 1399/3746 images processed (37.35%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1400/3746 images processed (37.37%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1401/3746 images processed (37.40%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1402/3746 images processed (37.43%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1403/3746 images processed (37.45%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 1404/3746 images processed (37.48%)
# 1/1 [==============================] - 0s 395ms/step
# Progress: 1405/3746 images processed (37.51%)
# 1/1 [==============================] - 0s 456ms/step
# Progress: 1406/3746 images processed (37.53%)
# 1/1 [==============================] - 0s 412ms/step
# Progress: 1407/3746 images processed (37.56%)
# 1/1 [==============================] - 0s 444ms/step
# Progress: 1408/3746 images processed (37.59%)
# 1/1 [==============================] - 0s 438ms/step
# Progress: 1409/3746 images processed (37.61%)
# 1/1 [==============================] - 0s 404ms/step
# Progress: 1410/3746 images processed (37.64%)
# 1/1 [==============================] - 0s 363ms/step
# Progress: 1411/3746 images processed (37.67%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1412/3746 images processed (37.69%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1413/3746 images processed (37.72%)
# 1/1 [==============================] - 0s 261ms/step
# Progress: 1414/3746 images processed (37.75%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1415/3746 images processed (37.77%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1416/3746 images processed (37.80%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1417/3746 images processed (37.83%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1418/3746 images processed (37.85%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1419/3746 images processed (37.88%)
# 1/1 [==============================] - 0s 273ms/step
# Progress: 1420/3746 images processed (37.91%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1421/3746 images processed (37.93%)
# 1/1 [==============================] - 0s 261ms/step
# Progress: 1422/3746 images processed (37.96%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1423/3746 images processed (37.99%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1424/3746 images processed (38.01%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1425/3746 images processed (38.04%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1426/3746 images processed (38.07%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1427/3746 images processed (38.09%)
# 1/1 [==============================] - 0s 236ms/step
# Progress: 1428/3746 images processed (38.12%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1429/3746 images processed (38.15%)
# 1/1 [==============================] - 0s 266ms/step
# Progress: 1430/3746 images processed (38.17%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1431/3746 images processed (38.20%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1432/3746 images processed (38.23%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1433/3746 images processed (38.25%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1434/3746 images processed (38.28%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1435/3746 images processed (38.31%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 1436/3746 images processed (38.33%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1437/3746 images processed (38.36%)
# 1/1 [==============================] - 0s 374ms/step
# Progress: 1438/3746 images processed (38.39%)
# 1/1 [==============================] - 0s 421ms/step
# Progress: 1439/3746 images processed (38.41%)
# 1/1 [==============================] - 0s 399ms/step
# Progress: 1440/3746 images processed (38.44%)
# 1/1 [==============================] - 0s 422ms/step
# Progress: 1441/3746 images processed (38.47%)
# 1/1 [==============================] - 0s 413ms/step
# Progress: 1442/3746 images processed (38.49%)
# 1/1 [==============================] - 0s 425ms/step
# Progress: 1443/3746 images processed (38.52%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1444/3746 images processed (38.55%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1445/3746 images processed (38.57%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1446/3746 images processed (38.60%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1447/3746 images processed (38.63%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 1448/3746 images processed (38.65%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1449/3746 images processed (38.68%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1450/3746 images processed (38.71%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1451/3746 images processed (38.73%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 1452/3746 images processed (38.76%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1453/3746 images processed (38.79%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 1454/3746 images processed (38.81%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 1455/3746 images processed (38.84%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1456/3746 images processed (38.87%)
# 1/1 [==============================] - 0s 236ms/step
# Progress: 1457/3746 images processed (38.89%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 1458/3746 images processed (38.92%)
# 1/1 [==============================] - 0s 271ms/step
# Progress: 1459/3746 images processed (38.95%)
# 1/1 [==============================] - 0s 264ms/step
# Progress: 1460/3746 images processed (38.97%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1461/3746 images processed (39.00%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1462/3746 images processed (39.03%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1463/3746 images processed (39.05%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 1464/3746 images processed (39.08%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1465/3746 images processed (39.11%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1466/3746 images processed (39.14%)
# 1/1 [==============================] - 0s 261ms/step
# Progress: 1467/3746 images processed (39.16%)
# 1/1 [==============================] - 0s 265ms/step
# Progress: 1468/3746 images processed (39.19%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 1469/3746 images processed (39.22%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1470/3746 images processed (39.24%)
# 1/1 [==============================] - 0s 411ms/step
# Progress: 1471/3746 images processed (39.27%)
# 1/1 [==============================] - 0s 447ms/step
# Progress: 1472/3746 images processed (39.30%)
# 1/1 [==============================] - 0s 457ms/step
# Progress: 1473/3746 images processed (39.32%)
# 1/1 [==============================] - 0s 452ms/step
# Progress: 1474/3746 images processed (39.35%)
# 1/1 [==============================] - 0s 450ms/step
# Progress: 1475/3746 images processed (39.38%)
# 1/1 [==============================] - 0s 275ms/step
# Progress: 1476/3746 images processed (39.40%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1477/3746 images processed (39.43%)
# 1/1 [==============================] - 0s 273ms/step
# Progress: 1478/3746 images processed (39.46%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1479/3746 images processed (39.48%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1480/3746 images processed (39.51%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1481/3746 images processed (39.54%)
# 1/1 [==============================] - 0s 235ms/step
# Progress: 1482/3746 images processed (39.56%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1483/3746 images processed (39.59%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1484/3746 images processed (39.62%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1485/3746 images processed (39.64%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1486/3746 images processed (39.67%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1487/3746 images processed (39.70%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1488/3746 images processed (39.72%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 1489/3746 images processed (39.75%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1490/3746 images processed (39.78%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1491/3746 images processed (39.80%)
# 1/1 [==============================] - 0s 266ms/step
# Progress: 1492/3746 images processed (39.83%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 1493/3746 images processed (39.86%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1494/3746 images processed (39.88%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 1495/3746 images processed (39.91%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1496/3746 images processed (39.94%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1497/3746 images processed (39.96%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1498/3746 images processed (39.99%)
# 1/1 [==============================] - 0s 270ms/step
# Progress: 1499/3746 images processed (40.02%)
# 1/1 [==============================] - 0s 276ms/step
# Progress: 1500/3746 images processed (40.04%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1501/3746 images processed (40.07%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1502/3746 images processed (40.10%)
# 1/1 [==============================] - 0s 370ms/step
# Progress: 1503/3746 images processed (40.12%)
# 1/1 [==============================] - 0s 429ms/step
# Progress: 1504/3746 images processed (40.15%)
# 1/1 [==============================] - 0s 414ms/step
# Progress: 1505/3746 images processed (40.18%)
# 1/1 [==============================] - 0s 439ms/step
# Progress: 1506/3746 images processed (40.20%)
# 1/1 [==============================] - 0s 411ms/step
# Progress: 1507/3746 images processed (40.23%)
# 1/1 [==============================] - 0s 410ms/step
# Progress: 1508/3746 images processed (40.26%)
# 1/1 [==============================] - 0s 278ms/step
# Progress: 1509/3746 images processed (40.28%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1510/3746 images processed (40.31%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1511/3746 images processed (40.34%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1512/3746 images processed (40.36%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1513/3746 images processed (40.39%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1514/3746 images processed (40.42%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1515/3746 images processed (40.44%)
# 1/1 [==============================] - 0s 275ms/step
# Progress: 1516/3746 images processed (40.47%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1517/3746 images processed (40.50%)
# 1/1 [==============================] - 0s 438ms/step
# Progress: 1518/3746 images processed (40.52%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 1519/3746 images processed (40.55%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1520/3746 images processed (40.58%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 1521/3746 images processed (40.60%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1522/3746 images processed (40.63%)
# 1/1 [==============================] - 0s 264ms/step
# Progress: 1523/3746 images processed (40.66%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 1524/3746 images processed (40.68%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 1525/3746 images processed (40.71%)
# 1/1 [==============================] - 0s 271ms/step
# Progress: 1526/3746 images processed (40.74%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 1527/3746 images processed (40.76%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 1528/3746 images processed (40.79%)
# 1/1 [==============================] - 0s 267ms/step
# Progress: 1529/3746 images processed (40.82%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1530/3746 images processed (40.84%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1531/3746 images processed (40.87%)
# 1/1 [==============================] - 0s 394ms/step
# Progress: 1532/3746 images processed (40.90%)
# 1/1 [==============================] - 0s 470ms/step
# Progress: 1533/3746 images processed (40.92%)
# 1/1 [==============================] - 0s 451ms/step
# Progress: 1534/3746 images processed (40.95%)
# 1/1 [==============================] - 0s 437ms/step
# Progress: 1535/3746 images processed (40.98%)
# 1/1 [==============================] - 0s 430ms/step
# Progress: 1536/3746 images processed (41.00%)
# 1/1 [==============================] - 0s 417ms/step
# Progress: 1537/3746 images processed (41.03%)
# 1/1 [==============================] - 0s 264ms/step
# Progress: 1538/3746 images processed (41.06%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1539/3746 images processed (41.08%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 1540/3746 images processed (41.11%)
# 1/1 [==============================] - 0s 280ms/step
# Progress: 1541/3746 images processed (41.14%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 1542/3746 images processed (41.16%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1543/3746 images processed (41.19%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 1544/3746 images processed (41.22%)
# 1/1 [==============================] - 0s 230ms/step
# Progress: 1545/3746 images processed (41.24%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1546/3746 images processed (41.27%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 1547/3746 images processed (41.30%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1548/3746 images processed (41.32%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1549/3746 images processed (41.35%)
# 1/1 [==============================] - 0s 268ms/step
# Progress: 1550/3746 images processed (41.38%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 1551/3746 images processed (41.40%)
# 1/1 [==============================] - 0s 268ms/step
# Progress: 1552/3746 images processed (41.43%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 1553/3746 images processed (41.46%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1554/3746 images processed (41.48%)
# 1/1 [==============================] - 0s 235ms/step
# Progress: 1555/3746 images processed (41.51%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 1556/3746 images processed (41.54%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1557/3746 images processed (41.56%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1558/3746 images processed (41.59%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1559/3746 images processed (41.62%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1560/3746 images processed (41.64%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 1561/3746 images processed (41.67%)
# 1/1 [==============================] - 0s 265ms/step
# Progress: 1562/3746 images processed (41.70%)
# 1/1 [==============================] - 0s 272ms/step
# Progress: 1563/3746 images processed (41.72%)
# 1/1 [==============================] - 0s 369ms/step
# Progress: 1564/3746 images processed (41.75%)
# 1/1 [==============================] - 0s 436ms/step
# Progress: 1565/3746 images processed (41.78%)
# 1/1 [==============================] - 0s 453ms/step
# Progress: 1566/3746 images processed (41.80%)
# 1/1 [==============================] - 0s 427ms/step
# Progress: 1567/3746 images processed (41.83%)
# 1/1 [==============================] - 0s 417ms/step
# Progress: 1568/3746 images processed (41.86%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1569/3746 images processed (41.88%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1570/3746 images processed (41.91%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 1571/3746 images processed (41.94%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1572/3746 images processed (41.96%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1573/3746 images processed (41.99%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1574/3746 images processed (42.02%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1575/3746 images processed (42.04%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1576/3746 images processed (42.07%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1577/3746 images processed (42.10%)
# 1/1 [==============================] - 0s 235ms/step
# Progress: 1578/3746 images processed (42.12%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1579/3746 images processed (42.15%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1580/3746 images processed (42.18%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 1581/3746 images processed (42.21%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1582/3746 images processed (42.23%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 1583/3746 images processed (42.26%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1584/3746 images processed (42.29%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1585/3746 images processed (42.31%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 1586/3746 images processed (42.34%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1587/3746 images processed (42.37%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1588/3746 images processed (42.39%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 1589/3746 images processed (42.42%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1590/3746 images processed (42.45%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1591/3746 images processed (42.47%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1592/3746 images processed (42.50%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 1593/3746 images processed (42.53%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1594/3746 images processed (42.55%)
# 1/1 [==============================] - 0s 261ms/step
# Progress: 1595/3746 images processed (42.58%)
# 1/1 [==============================] - 0s 336ms/step
# Progress: 1596/3746 images processed (42.61%)
# 1/1 [==============================] - 0s 438ms/step
# Progress: 1597/3746 images processed (42.63%)
# 1/1 [==============================] - 0s 476ms/step
# Progress: 1598/3746 images processed (42.66%)
# 1/1 [==============================] - 0s 419ms/step
# Progress: 1599/3746 images processed (42.69%)
# 1/1 [==============================] - 0s 384ms/step
# Progress: 1600/3746 images processed (42.71%)
# 1/1 [==============================] - 0s 406ms/step
# Progress: 1601/3746 images processed (42.74%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1602/3746 images processed (42.77%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1603/3746 images processed (42.79%)
# 1/1 [==============================] - 0s 268ms/step
# Progress: 1604/3746 images processed (42.82%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 1605/3746 images processed (42.85%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1606/3746 images processed (42.87%)
# 1/1 [==============================] - 0s 280ms/step
# Progress: 1607/3746 images processed (42.90%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 1608/3746 images processed (42.93%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1609/3746 images processed (42.95%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1610/3746 images processed (42.98%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1611/3746 images processed (43.01%)
# 1/1 [==============================] - 0s 280ms/step
# Progress: 1612/3746 images processed (43.03%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 1613/3746 images processed (43.06%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1614/3746 images processed (43.09%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1615/3746 images processed (43.11%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1616/3746 images processed (43.14%)
# 1/1 [==============================] - 0s 271ms/step
# Progress: 1617/3746 images processed (43.17%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 1618/3746 images processed (43.19%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1619/3746 images processed (43.22%)
# 1/1 [==============================] - 0s 273ms/step
# Progress: 1620/3746 images processed (43.25%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 1621/3746 images processed (43.27%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1622/3746 images processed (43.30%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1623/3746 images processed (43.33%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 1624/3746 images processed (43.35%)
# 1/1 [==============================] - 0s 281ms/step
# Progress: 1625/3746 images processed (43.38%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1626/3746 images processed (43.41%)
# 1/1 [==============================] - 0s 470ms/step
# Progress: 1627/3746 images processed (43.43%)
# 1/1 [==============================] - 0s 408ms/step
# Progress: 1628/3746 images processed (43.46%)
# 1/1 [==============================] - 0s 444ms/step
# Progress: 1629/3746 images processed (43.49%)
# 1/1 [==============================] - 0s 431ms/step
# Progress: 1630/3746 images processed (43.51%)
# 1/1 [==============================] - 0s 405ms/step
# Progress: 1631/3746 images processed (43.54%)
# 1/1 [==============================] - 0s 428ms/step
# Progress: 1632/3746 images processed (43.57%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1633/3746 images processed (43.59%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1634/3746 images processed (43.62%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1635/3746 images processed (43.65%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1636/3746 images processed (43.67%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 1637/3746 images processed (43.70%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 1638/3746 images processed (43.73%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1639/3746 images processed (43.75%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 1640/3746 images processed (43.78%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 1641/3746 images processed (43.81%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1642/3746 images processed (43.83%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 1643/3746 images processed (43.86%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1644/3746 images processed (43.89%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 1645/3746 images processed (43.91%)
# 1/1 [==============================] - 0s 273ms/step
# Progress: 1646/3746 images processed (43.94%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1647/3746 images processed (43.97%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 1648/3746 images processed (43.99%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1649/3746 images processed (44.02%)
# 1/1 [==============================] - 0s 235ms/step
# Progress: 1650/3746 images processed (44.05%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1651/3746 images processed (44.07%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1652/3746 images processed (44.10%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1653/3746 images processed (44.13%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1654/3746 images processed (44.15%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1655/3746 images processed (44.18%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1656/3746 images processed (44.21%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1657/3746 images processed (44.23%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1658/3746 images processed (44.26%)
# 1/1 [==============================] - 0s 398ms/step
# Progress: 1659/3746 images processed (44.29%)
# 1/1 [==============================] - 0s 405ms/step
# Progress: 1660/3746 images processed (44.31%)
# 1/1 [==============================] - 0s 433ms/step
# Progress: 1661/3746 images processed (44.34%)
# 1/1 [==============================] - 0s 447ms/step
# Progress: 1662/3746 images processed (44.37%)
# 1/1 [==============================] - 0s 426ms/step
# Progress: 1663/3746 images processed (44.39%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 1664/3746 images processed (44.42%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1665/3746 images processed (44.45%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 1666/3746 images processed (44.47%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1667/3746 images processed (44.50%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 1668/3746 images processed (44.53%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 1669/3746 images processed (44.55%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1670/3746 images processed (44.58%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 1671/3746 images processed (44.61%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1672/3746 images processed (44.63%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 1673/3746 images processed (44.66%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1674/3746 images processed (44.69%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1675/3746 images processed (44.71%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1676/3746 images processed (44.74%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1677/3746 images processed (44.77%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1678/3746 images processed (44.79%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 1679/3746 images processed (44.82%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 1680/3746 images processed (44.85%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 1681/3746 images processed (44.87%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 1682/3746 images processed (44.90%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1683/3746 images processed (44.93%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1684/3746 images processed (44.95%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1685/3746 images processed (44.98%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1686/3746 images processed (45.01%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1687/3746 images processed (45.03%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1688/3746 images processed (45.06%)
# 1/1 [==============================] - 0s 316ms/step
# Progress: 1689/3746 images processed (45.09%)
# 1/1 [==============================] - 0s 457ms/step
# Progress: 1690/3746 images processed (45.11%)
# 1/1 [==============================] - 0s 441ms/step
# Progress: 1691/3746 images processed (45.14%)
# 1/1 [==============================] - 0s 465ms/step
# Progress: 1692/3746 images processed (45.17%)
# 1/1 [==============================] - 0s 437ms/step
# Progress: 1693/3746 images processed (45.19%)
# 1/1 [==============================] - 0s 407ms/step
# Progress: 1694/3746 images processed (45.22%)
# 1/1 [==============================] - 0s 236ms/step
# Progress: 1695/3746 images processed (45.25%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1696/3746 images processed (45.27%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1697/3746 images processed (45.30%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1698/3746 images processed (45.33%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 1699/3746 images processed (45.36%)
# 1/1 [==============================] - 0s 264ms/step
# Progress: 1700/3746 images processed (45.38%)
# 1/1 [==============================] - 0s 270ms/step
# Progress: 1701/3746 images processed (45.41%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1702/3746 images processed (45.44%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 1703/3746 images processed (45.46%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 1704/3746 images processed (45.49%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1705/3746 images processed (45.52%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 1706/3746 images processed (45.54%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 1707/3746 images processed (45.57%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1708/3746 images processed (45.60%)
# 1/1 [==============================] - 0s 276ms/step
# Progress: 1709/3746 images processed (45.62%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1710/3746 images processed (45.65%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 1711/3746 images processed (45.68%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1712/3746 images processed (45.70%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 1713/3746 images processed (45.73%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 1714/3746 images processed (45.76%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 1715/3746 images processed (45.78%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 1716/3746 images processed (45.81%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 1717/3746 images processed (45.84%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 1718/3746 images processed (45.86%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 1719/3746 images processed (45.89%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 1720/3746 images processed (45.92%)
# 1/1 [==============================] - 0s 419ms/step
# Progress: 1721/3746 images processed (45.94%)
# 1/1 [==============================] - 0s 421ms/step
# Progress: 1722/3746 images processed (45.97%)
# 1/1 [==============================] - 0s 414ms/step
# Progress: 1723/3746 images processed (46.00%)
# 1/1 [==============================] - 0s 419ms/step
# Progress: 1724/3746 images processed (46.02%)
# 1/1 [==============================] - 0s 423ms/step
# Progress: 1725/3746 images processed (46.05%)
# 1/1 [==============================] - 0s 407ms/step
# Progress: 1726/3746 images processed (46.08%)
# 1/1 [==============================] - 0s 256ms/step
# ...
# 1/1 [==============================] - 0s 250ms/step
# Progress: 3582/3746 images processed (95.62%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 3583/3746 images processed (95.65%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 3584/3746 images processed (95.68%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 3585/3746 images processed (95.70%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 3586/3746 images processed (95.73%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 3587/3746 images processed (95.76%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 3588/3746 images processed (95.78%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 3589/3746 images processed (95.81%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 3590/3746 images processed (95.84%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 3591/3746 images processed (95.86%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 3592/3746 images processed (95.89%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 3593/3746 images processed (95.92%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 3594/3746 images processed (95.94%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 3595/3746 images processed (95.97%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 3596/3746 images processed (96.00%)
# 1/1 [==============================] - 0s 272ms/step
# Progress: 3597/3746 images processed (96.02%)
# 1/1 [==============================] - 0s 268ms/step
# Progress: 3598/3746 images processed (96.05%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 3599/3746 images processed (96.08%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 3600/3746 images processed (96.10%)
# 1/1 [==============================] - 0s 407ms/step
# Progress: 3601/3746 images processed (96.13%)
# 1/1 [==============================] - 0s 408ms/step
# Progress: 3602/3746 images processed (96.16%)
# 1/1 [==============================] - 0s 411ms/step
# Progress: 3603/3746 images processed (96.18%)
# 1/1 [==============================] - 0s 421ms/step
# Progress: 3604/3746 images processed (96.21%)
# 1/1 [==============================] - 0s 437ms/step
# Progress: 3605/3746 images processed (96.24%)
# 1/1 [==============================] - 0s 407ms/step
# Progress: 3606/3746 images processed (96.26%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 3607/3746 images processed (96.29%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 3608/3746 images processed (96.32%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 3609/3746 images processed (96.34%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 3610/3746 images processed (96.37%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 3611/3746 images processed (96.40%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 3612/3746 images processed (96.42%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 3613/3746 images processed (96.45%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 3614/3746 images processed (96.48%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 3615/3746 images processed (96.50%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 3616/3746 images processed (96.53%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 3617/3746 images processed (96.56%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 3618/3746 images processed (96.58%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 3619/3746 images processed (96.61%)
# 1/1 [==============================] - 0s 285ms/step
# Progress: 3620/3746 images processed (96.64%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 3621/3746 images processed (96.66%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 3622/3746 images processed (96.69%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 3623/3746 images processed (96.72%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 3624/3746 images processed (96.74%)
# 1/1 [==============================] - 0s 264ms/step
# Progress: 3625/3746 images processed (96.77%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 3626/3746 images processed (96.80%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 3627/3746 images processed (96.82%)
# 1/1 [==============================] - 0s 261ms/step
# Progress: 3628/3746 images processed (96.85%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 3629/3746 images processed (96.88%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 3630/3746 images processed (96.90%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 3631/3746 images processed (96.93%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 3632/3746 images processed (96.96%)
# 1/1 [==============================] - 0s 294ms/step
# Progress: 3633/3746 images processed (96.98%)
# 1/1 [==============================] - 0s 448ms/step
# Progress: 3634/3746 images processed (97.01%)
# 1/1 [==============================] - 0s 418ms/step
# Progress: 3635/3746 images processed (97.04%)
# 1/1 [==============================] - 0s 428ms/step
# Progress: 3636/3746 images processed (97.06%)
# 1/1 [==============================] - 0s 428ms/step
# Progress: 3637/3746 images processed (97.09%)
# 1/1 [==============================] - 0s 422ms/step
# Progress: 3638/3746 images processed (97.12%)
# 1/1 [==============================] - 0s 419ms/step
# Progress: 3639/3746 images processed (97.14%)
# 1/1 [==============================] - 0s 311ms/step
# Progress: 3640/3746 images processed (97.17%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 3641/3746 images processed (97.20%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 3642/3746 images processed (97.22%)
# 1/1 [==============================] - 0s 252ms/step
# Progress: 3643/3746 images processed (97.25%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 3644/3746 images processed (97.28%)
# 1/1 [==============================] - 0s 236ms/step
# Progress: 3645/3746 images processed (97.30%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 3646/3746 images processed (97.33%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 3647/3746 images processed (97.36%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 3648/3746 images processed (97.38%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 3649/3746 images processed (97.41%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 3650/3746 images processed (97.44%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 3651/3746 images processed (97.46%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 3652/3746 images processed (97.49%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 3653/3746 images processed (97.52%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 3654/3746 images processed (97.54%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 3655/3746 images processed (97.57%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 3656/3746 images processed (97.60%)
# 1/1 [==============================] - 0s 236ms/step
# Progress: 3657/3746 images processed (97.62%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 3658/3746 images processed (97.65%)
# 1/1 [==============================] - 0s 253ms/step
# Progress: 3659/3746 images processed (97.68%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 3660/3746 images processed (97.70%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 3661/3746 images processed (97.73%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 3662/3746 images processed (97.76%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 3663/3746 images processed (97.78%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 3664/3746 images processed (97.81%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 3665/3746 images processed (97.84%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 3666/3746 images processed (97.86%)
# 1/1 [==============================] - 0s 370ms/step
# Progress: 3667/3746 images processed (97.89%)
# 1/1 [==============================] - 0s 443ms/step
# Progress: 3668/3746 images processed (97.92%)
# 1/1 [==============================] - 0s 449ms/step
# Progress: 3669/3746 images processed (97.94%)
# 1/1 [==============================] - 0s 435ms/step
# Progress: 3670/3746 images processed (97.97%)
# 1/1 [==============================] - 0s 427ms/step
# Progress: 3671/3746 images processed (98.00%)
# 1/1 [==============================] - 0s 402ms/step
# Progress: 3672/3746 images processed (98.02%)
# 1/1 [==============================] - 0s 334ms/step
# Progress: 3673/3746 images processed (98.05%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 3674/3746 images processed (98.08%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 3675/3746 images processed (98.10%)
# 1/1 [==============================] - 0s 267ms/step
# Progress: 3676/3746 images processed (98.13%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 3677/3746 images processed (98.16%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 3678/3746 images processed (98.18%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 3679/3746 images processed (98.21%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 3680/3746 images processed (98.24%)
# 1/1 [==============================] - 0s 269ms/step
# Progress: 3681/3746 images processed (98.26%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 3682/3746 images processed (98.29%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 3683/3746 images processed (98.32%)
# 1/1 [==============================] - 0s 260ms/step
# Progress: 3684/3746 images processed (98.34%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 3685/3746 images processed (98.37%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 3686/3746 images processed (98.40%)
# 1/1 [==============================] - 0s 264ms/step
# Progress: 3687/3746 images processed (98.42%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 3688/3746 images processed (98.45%)
# 1/1 [==============================] - 0s 264ms/step
# Progress: 3689/3746 images processed (98.48%)
# 1/1 [==============================] - 0s 267ms/step
# Progress: 3690/3746 images processed (98.51%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 3691/3746 images processed (98.53%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 3692/3746 images processed (98.56%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 3693/3746 images processed (98.59%)
# 1/1 [==============================] - 0s 238ms/step
# Progress: 3694/3746 images processed (98.61%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 3695/3746 images processed (98.64%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 3696/3746 images processed (98.67%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 3697/3746 images processed (98.69%)
# 1/1 [==============================] - 0s 259ms/step
# Progress: 3698/3746 images processed (98.72%)
# 1/1 [==============================] - 0s 250ms/step
# Progress: 3699/3746 images processed (98.75%)
# 1/1 [==============================] - 0s 308ms/step
# Progress: 3700/3746 images processed (98.77%)
# 1/1 [==============================] - 0s 456ms/step
# Progress: 3701/3746 images processed (98.80%)
# 1/1 [==============================] - 0s 408ms/step
# Progress: 3702/3746 images processed (98.83%)
# 1/1 [==============================] - 0s 425ms/step
# Progress: 3703/3746 images processed (98.85%)
# 1/1 [==============================] - 0s 425ms/step
# Progress: 3704/3746 images processed (98.88%)
# 1/1 [==============================] - 0s 428ms/step
# Progress: 3705/3746 images processed (98.91%)
# 1/1 [==============================] - 0s 299ms/step
# Progress: 3706/3746 images processed (98.93%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 3707/3746 images processed (98.96%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 3708/3746 images processed (98.99%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 3709/3746 images processed (99.01%)
# 1/1 [==============================] - 0s 263ms/step
# Progress: 3710/3746 images processed (99.04%)
# 1/1 [==============================] - 0s 255ms/step
# Progress: 3711/3746 images processed (99.07%)
# 1/1 [==============================] - 0s 268ms/step
# Progress: 3712/3746 images processed (99.09%)
# 1/1 [==============================] - 0s 257ms/step
# Progress: 3713/3746 images processed (99.12%)
# 1/1 [==============================] - 0s 247ms/step
# Progress: 3714/3746 images processed (99.15%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 3715/3746 images processed (99.17%)
# 1/1 [==============================] - 0s 262ms/step
# Progress: 3716/3746 images processed (99.20%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 3717/3746 images processed (99.23%)
# 1/1 [==============================] - 0s 245ms/step
# Progress: 3718/3746 images processed (99.25%)
# 1/1 [==============================] - 0s 254ms/step
# Progress: 3719/3746 images processed (99.28%)
# 1/1 [==============================] - 0s 239ms/step
# Progress: 3720/3746 images processed (99.31%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 3721/3746 images processed (99.33%)
# 1/1 [==============================] - 0s 241ms/step
# Progress: 3722/3746 images processed (99.36%)
# 1/1 [==============================] - 0s 243ms/step
# Progress: 3723/3746 images processed (99.39%)
# 1/1 [==============================] - 0s 237ms/step
# Progress: 3724/3746 images processed (99.41%)
# 1/1 [==============================] - 0s 249ms/step
# Progress: 3725/3746 images processed (99.44%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 3726/3746 images processed (99.47%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 3727/3746 images processed (99.49%)
# 1/1 [==============================] - 0s 242ms/step
# Progress: 3728/3746 images processed (99.52%)
# 1/1 [==============================] - 0s 248ms/step
# Progress: 3729/3746 images processed (99.55%)
# 1/1 [==============================] - 0s 256ms/step
# Progress: 3730/3746 images processed (99.57%)
# 1/1 [==============================] - 0s 246ms/step
# Progress: 3731/3746 images processed (99.60%)
# 1/1 [==============================] - 0s 244ms/step
# Progress: 3732/3746 images processed (99.63%)
# 1/1 [==============================] - 0s 390ms/step
# Progress: 3733/3746 images processed (99.65%)
# 1/1 [==============================] - 0s 444ms/step
# Progress: 3734/3746 images processed (99.68%)
# 1/1 [==============================] - 0s 378ms/step
# Progress: 3735/3746 images processed (99.71%)
# 1/1 [==============================] - 0s 469ms/step
# Progress: 3736/3746 images processed (99.73%)
# 1/1 [==============================] - 0s 433ms/step
# Progress: 3737/3746 images processed (99.76%)
# 1/1 [==============================] - 0s 431ms/step
# Progress: 3738/3746 images processed (99.79%)
# 1/1 [==============================] - 0s 407ms/step
# Progress: 3739/3746 images processed (99.81%)
# 1/1 [==============================] - 0s 251ms/step
# Progress: 3740/3746 images processed (99.84%)
# 1/1 [==============================] - 0s 240ms/step
# Progress: 3741/3746 images processed (99.87%)
# 1/1 [==============================] - 0s 258ms/step
# Progress: 3742/3746 images processed (99.89%)
# All features extracted and saved.

# %%
import torch
from transformers import BeitForImageClassification, BeitFeatureExtractor
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.preprocessing import image as keras_image
from tensorflow.keras.models import Model
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pickle
from PIL import Image

# Load the fine-tuned classification model
classification_model_path = '/content/drive/MyDrive/Project_IR/fine_tuned_model'
classification_model = BeitForImageClassification.from_pretrained(classification_model_path)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
classification_model.to(device).eval()

# Initialize InceptionV3 for feature extraction
inception_model = InceptionV3(weights='imagenet', include_top=False, pooling='avg')
feature_model = Model(inputs=inception_model.input, outputs=inception_model.output)

# Class names for classification
class_names = [
    "Ajanta Caves", "Charar-E- Sharif", "Chhota Imambara", "Ellora Caves", "Fatehpur Sikiri",
    "Hawa Mahal", "Gateway of India", "Khajuraho", "Sun Temple Konark", "Alai Darwaza",
    "Alai Minar", "Basilica of Bom Jesus", "Charminar", "Golden Temple", "Iron Pillar",
    "Jamali Kamali Tomb", "Lotus Temple", "Mysore Palace", "Qutub Minar", "Taj Mahal",
    "Tanjavur Temple", "Victoria Memorial"
]


def preprocess_image_inception(image_path):
    img = keras_image.load_img(image_path, target_size=(299, 299))
    img_array = keras_image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    return preprocess_input(img_array)

def extract_features_inception(image_path, model):
    img_array = preprocess_image_inception(image_path)
    features = model.predict(img_array)
    return features.flatten()

def classify_image(image_path, model, device):
    transform = Compose([
        Resize((224, 224)),  # Resize image for Beit model
        ToTensor(),
        Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    image = Image.open(image_path).convert("RGB")
    image_tensor = transform(image).unsqueeze(0).to(device)
    with torch.no_grad():
        outputs = model(image_tensor)
        preds = outputs.logits.softmax(dim=-1)
        predicted_index = preds.argmax(1).item()
    return class_names[predicted_index]


def load_data(file_name):
    with open(file_name, 'rb') as file:
        data = pickle.load(file)
    return data['features'], data['paths']

def find_similar_images(image_input, dataset_features):
    input_features = extract_features_inception(image_input, feature_model)
    similarities = cosine_similarity([input_features], dataset_features)
    top_10_indices = np.argsort(similarities[0])[-10:][::-1]
    return top_10_indices

# Use the functions
image_input = input("Enter image path: ")
features_file_path = '/content/drive/MyDrive/Project_IR/dataset_features_Monuments.pkl'
dataset_features, dataset_image_paths = load_data(features_file_path)

predicted_class = classify_image(image_input, classification_model, device)
top_10_indices = find_similar_images(image_input, dataset_features)
top_10_similar_images = [dataset_image_paths[i] for i in top_10_indices]

print(f"Predicted class: {predicted_class}")
print("Top 10 similar images:")
for path in top_10_similar_images:
    print(path)
# Out:
# Enter image path: /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/test/Chhota_Imambara/1.jpg
# 1/1 [==============================] - 2s 2s/step
# Predicted class: Chhota Imambara
# Top 10 similar images:
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img1 - Copy.jpg
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img1.jpg
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img11 - Copy.jpg
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img11.jpg
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img26 - Copy.jpg
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img26.jpg
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img32 - Copy.jpg
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img32.jpg
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img33 - Copy.jpg
# /content/drive/MyDrive/Project_IR/Dataset_Indian-monuments/images/train/Chhota_Imambara/img33.jpg
