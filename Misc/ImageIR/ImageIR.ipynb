# %%
# Create the KeyWord Mapping

import csv
import os

Keyterms = {
    'Tanjore': ['temple', 'art', 'culture', 'South India', 'painting'],
    'lotus_temple': ['architecture', 'delhi', 'bahai', 'worship', 'modern'],
    'manipuri': ['dance', 'northeast', 'manipur', 'traditional', 'culture'],
    'pattachitra': ['art', 'painting', 'odisha', 'folk', 'traditional'],
    'alai_minar': ['architecture', 'delhi', 'unfinished', 'monument', 'history'],
    'basilica_of_bom_jesus': ['church', 'goa', 'christianity', 'history', 'UNESCO'],
    'golden temple': ['sikh', 'amritsar', 'punjab', 'worship', 'architecture'],
    'Warli': ['art', 'tribal', 'maharashtra', 'painting', 'traditional'],
    'Kalamkari': ['art', 'textile', 'andhra pradesh', 'painting', 'traditional'],
    'Portrait': ['art', 'painting', 'portrait', 'canvas', 'artist'],
    'Khajuraho': ['temple', 'erotic', 'madhya pradesh', 'sculpture', 'architecture'],
    'bharatanatyam': ['dance', 'classical', 'Tamil Nadu', 'performance', 'tradition'],
    'hawa mahal pics': ['architecture', 'jaipur', 'rajasthan', 'pink city', 'palace'],
    'test': ['test', 'data', 'sample', 'experiment', 'analysis'],
    'Gateway of India': ['monument', 'mumbai', 'gateway', 'architecture', 'history'],
    'Fatehpur Sikri': ['fort', 'agra', 'mughal', 'architecture', 'unesco'],
    'kathakali': ['dance', 'kerala', 'classical', 'performance', 'tradition'],
    'Madhubani': ['art', 'painting', 'bihar', 'folk', 'traditional'],
    'kuchipudi': ['dance', 'andhra pradesh', 'classical', 'performance', 'tradition'],
    'Sun Temple Konark': ['temple', 'odisha', 'sun god', 'sculpture', 'architecture'],
    'iron_pillar': ['pillar', 'delhi', 'qutub minar', 'iron', 'history'],
    'alai_darwaza': ['architecture', 'delhi', 'monument', 'gateway', 'mughal'],
    'Chhota_Imambara': ['mosque', 'lucknow', 'nawab', 'architecture', 'history'],
    'charminar': ['mosque', 'hyderabad', 'monument', 'architecture', 'landmark'],
    'Kangra': ['fort', 'himachal pradesh', 'kangra valley', 'history', 'architecture'],
    'Hawa mahal': ['architecture', 'jaipur', 'rajasthan', 'pink city', 'palace'],
    'Ellora Caves': ['cave', 'maharashtra', 'unesco', 'sculpture', 'architecture'],
    'tanjavur temple': ['temple', 'tamil nadu', 'architecture', 'chola', 'unesco'],
    'Humayun_s Tomb': ['tomb', 'delhi', 'mughal', 'architecture', 'unesco'],
    'mysore_palace': ['palace', 'mysore', 'karnataka', 'architecture', 'royalty'],
    'India_gate': ['war memorial', 'delhi', 'architecture', 'india', 'history'],
    'odissi': ['dance', 'odisha', 'classical', 'performance', 'tradition'],
    'Charar-E- Sharif': ['mosque', 'kashmir', 'sufi', 'architecture', 'history'],
    'tajmahal': ['mausoleum', 'agra', 'mughal', 'architecture', 'unesco'],
    'victoria memorial': ['memorial', 'kolkata', 'architecture', 'history', 'british'],
    'sattriya': ['dance', 'assam', 'classical', 'performance', 'tradition'],
    'mohiniyattam': ['dance', 'kerala', 'classical', 'performance', 'tradition'],
    'Ajanta Caves': ['cave', 'maharashtra', 'unesco', 'sculpture', 'architecture'],
    'kathak': ['dance', 'uttar pradesh', 'classical', 'performance', 'tradition'],
    'Mural': ['art', 'painting', 'wall', 'mural', 'artist'],
    'qutub_minar': ['minaret', 'delhi', 'monument', 'history', 'architecture'],
    'India gate pics': ['war memorial', 'delhi', 'architecture', 'india', 'history'],
    'jamali_kamali_tomb': ['tomb', 'delhi', 'architecture', 'history', 'jamali kamali']
}


def add_image_info_to_csv(image_path, class_name, key_terms):
    csv_file_name = 'Image_Keyterms.csv'
    file_exists = os.path.isfile(csv_file_name)
    with open(csv_file_name, mode='a', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        if not file_exists:
            writer.writerow(['Path', 'Class', 'Keyterms'])
        image_path = "'{}'".format(image_path)
        class_name = "'{}'".format(class_name)
        writer.writerow([image_path, class_name] + [key_terms])

def process_images_in_directory(directory_path):
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith('.jpg') or file.endswith('.png'):  
                image_path = os.path.join(root, file)
                class_name = os.path.basename(root)
                key_terms = Keyterms[class_name]
                add_image_info_to_csv(image_path, class_name, key_terms)

directory_path = '../Image Data'
process_images_in_directory(directory_path)

# %%
# Data Analysis

from PIL import Image
import os
import matplotlib.pyplot as plt
import numpy as np
import cv2

def analyze_image_sizes_and_formats(image_directory):
    image_sizes = []
    image_formats = []
    
    for root, dirs, files in os.walk(image_directory):
        for file in files:
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')):
                try:
                    with Image.open(os.path.join(root, file)) as img:
                        image_sizes.append(img.size)  
                        image_formats.append(img.format)
                except Exception as e:
                    print(f"Error opening {file}: {e}")

    widths, heights = zip(*image_sizes)
    avg_width = np.mean(widths)
    avg_height = np.mean(heights)
    print(f"Average image size: {avg_width:.2f} x {avg_height:.2f} (W x H)")
    print(f"Min image size: {min(widths)} x {min(heights)} (W x H)")
    print(f"Max image size: {max(widths)} x {max(heights)} (W x H)")
    format_distribution = {format: image_formats.count(format) for format in set(image_formats)}
    print(f"Image format distribution: {format_distribution}")

def analyze_class_distribution(image_directory):
    classes = [d for d in os.listdir(image_directory) if os.path.isdir(os.path.join(image_directory, d))]
    class_counts = {class_name: len(os.listdir(os.path.join(image_directory, class_name))) for class_name in classes}
    print(f"Class distribution: {class_counts}")
    

def analyze_color_distribution(image_directory):
    try:
        total_color_distribution = np.zeros(3)  
        
        total_images = 0
        
        for root, dirs, files in os.walk(image_directory):
            for file in files:
                if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')):
                    with Image.open(os.path.join(root, file)) as img:
                        img_data = np.array(img)
                        color_distribution = np.mean(img_data, axis=(0, 1))
                        total_color_distribution += color_distribution
                        total_images += 1
        avg_color_distribution = total_color_distribution / total_images
        plt.bar(range(len(avg_color_distribution)), avg_color_distribution)
        plt.title('Average Color Distribution')
        plt.xlabel('Channel')
        plt.ylabel('Mean Value')
        plt.show()
    except:
        print("Cannot get colour data")
    
def analyze_texture(image_directory):
    try:
        total_laplacian_var = 0
        total_images = 0
        
        for root, dirs, files in os.walk(image_directory):
            for file in files:
                if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')):
                    image_path = os.path.join(root, file)
                    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
                    laplacian_var = cv2.Laplacian(img, cv2.CV_64F).var()
                    total_laplacian_var += laplacian_var
                    total_images += 1
        
        avg_laplacian_var = total_laplacian_var / total_images
        print("Average Texture (Laplacian Variance):", avg_laplacian_var)
    except:
        print("Cannot get texture data")

def analyze_shape(image_directory):
    try:
        total_area = 0
        total_images = 0
        
        for root, dirs, files in os.walk(image_directory):
            for file in files:
                if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')):
                    image_path = os.path.join(root, file)
                    img = cv2.imread(image_path)
                    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                    _, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
                    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                    for cnt in contours:
                        area = cv2.contourArea(cnt)
                        total_area += area
                    
                    total_images += 1
        
        avg_area = total_area / total_images
        print("Average Shape (Contour Area):", avg_area)
    except:
        print("Cannot get shape data")


painting_train_directory = '../Image Data/Paintings/training'
painting_test_directory = '../Image Data/Paintings/testing'
monuments_train_directory = '../Image Data/Monuments/train'
monuments_test_directory = '../Image Data/Monuments/test'
dance_train_directory = '../Image Data/Dance/train'
dance_test_directory = '../Image Data/Dance/test'
print("PAINTING DATA:- ")
print()
print("Training")
analyze_image_sizes_and_formats(painting_train_directory)
analyze_class_distribution(painting_train_directory)
analyze_color_distribution(painting_train_directory)
analyze_texture(painting_train_directory)
analyze_shape(painting_train_directory)
print()
print("Testing")
analyze_image_sizes_and_formats(painting_test_directory)
analyze_class_distribution(painting_test_directory)
analyze_color_distribution(painting_test_directory)
analyze_texture(painting_test_directory)
analyze_shape(painting_test_directory)
print()
print()
print("MONUMENTS DATA:- ")
print()
print("Training")
analyze_image_sizes_and_formats(monuments_train_directory)
analyze_class_distribution(monuments_train_directory)
analyze_color_distribution(monuments_train_directory)
analyze_texture(monuments_train_directory)
analyze_shape(monuments_train_directory)
print()
print("Testing")
analyze_image_sizes_and_formats(monuments_test_directory)
analyze_class_distribution(monuments_test_directory)
analyze_color_distribution(monuments_test_directory)
analyze_texture(monuments_test_directory)
analyze_shape(monuments_test_directory)
print()
print()
print("DANCE DATA:- ")
print()
print("Training")
analyze_image_sizes_and_formats(dance_train_directory)
analyze_class_distribution(dance_train_directory)
analyze_color_distribution(dance_train_directory)
analyze_texture(dance_train_directory)
analyze_shape(dance_train_directory)
print()
print("Testing")
analyze_image_sizes_and_formats(dance_test_directory)
analyze_color_distribution(dance_test_directory)
analyze_texture(dance_test_directory)
analyze_shape(dance_test_directory)
print()
print()
# Out:
# PAINTING DATA:-
#
# Training
# Average image size: 224.17 x 219.76 (W x H)
# Min image size: 75 x 108 (W x H)
# Max image size: 450 x 309 (W x H)
# Image format distribution: {'PNG': 3, 'JPEG': 1749}
# Class distribution: {'Madhubani': 219, 'pattachitra': 219, 'Mural': 219, 'Tanjore': 219, 'Portrait': 219, 'Kangra': 219, 'Warli': 219, 'Kalamkari': 219}
# Average Texture (Laplacian Variance): 8947.167345101361
# Average Shape (Contour Area): 28743.277397260274
#
# Testing
# Average image size: 226.42 x 217.55 (W x H)
# Min image size: 84 x 92 (W x H)
# Max image size: 438 x 318 (W x H)
# Image format distribution: {'PNG': 2, 'JPEG': 742}
# Class distribution: {'Madhubani': 93, 'pattachitra': 93, 'Mural': 93, 'Tanjore': 93, 'Portrait': 93, 'Kangra': 93, 'Warli': 93, 'Kalamkari': 93}
# Average Texture (Laplacian Variance): 9228.801817826885
# Average Shape (Contour Area): 28309.82123655914
#
#
# MONUMENTS DATA:-
#
# Training
# Average image size: 634.56 x 507.82 (W x H)
# ...

# %%
import csv
import os
import ast
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    filtered_tokens = [word for word in tokens if word.isalnum() and word not in stop_words]
    return ' '.join(filtered_tokens)

def extract_key_terms(query):
    return preprocess_text(query)

def parse_key_terms(key_terms_str):
    return ast.literal_eval(key_terms_str)

def load_image_data(csv_file_name):
    data = []
    with open(csv_file_name, mode='r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            key_terms = parse_key_terms(row['Keyterms'])
            row['Keyterms'] = preprocess_text(' '.join(key_terms))
            data.append(row)
    return data

def find_most_relevant_images(user_query, image_data, top_n=10):
    key_terms = extract_key_terms(user_query)
    corpus = [item['Keyterms'] for item in image_data]
    corpus.append(key_terms)
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(corpus)
    similarity_matrix = cosine_similarity(tfidf_matrix[:-1], tfidf_matrix[-1])
    top_indices = similarity_matrix.argsort(axis=None)[-top_n:][::-1]
    results = [(image_data[idx]['Class'], image_data[idx]['Path']) for idx in top_indices]
    return results

csv_file_name = 'Image_Keyterms.csv'
image_data = load_image_data(csv_file_name)

user_query = input("Enter your query: ")
top_results = find_most_relevant_images(user_query, image_data)
print("Top 10 relevant images:")
for i, (image_class, most_relevant_image_path) in enumerate(top_results, 1):
    print(f"{i}. {image_class} - {most_relevant_image_path}")
# Out:
# Top 10 relevant images:
# 1. 'kathak' - '../Image Data/Dance/train/kathak/46.jpg'
# 2. 'Warli' - '../Image Data/Paintings/testing/Warli/p77.jpg'
# 3. 'Warli' - '../Image Data/Paintings/testing/Warli/p71.jpg'
# 4. 'Warli' - '../Image Data/Paintings/testing/Warli/p59.jpg'
# 5. 'Warli' - '../Image Data/Paintings/testing/Warli/p58.jpg'
# 6. 'Warli' - '../Image Data/Paintings/testing/Warli/p70.jpg'
# 7. 'Warli' - '../Image Data/Paintings/testing/Warli/p64.jpg'
# 8. 'Warli' - '../Image Data/Paintings/testing/Warli/p9.jpg'
# 9. 'Warli' - '../Image Data/Paintings/testing/Warli/p72.jpg'
# 10. 'Warli' - '../Image Data/Paintings/testing/Warli/p66.jpg'

# %%
import json
import os
import ast
import random
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def preprocess_text(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text.lower())
    filtered_tokens = [word for word in tokens if word.isalnum() and word not in stop_words]
    return ' '.join(filtered_tokens)

def extract_key_terms(query):
    return preprocess_text(query)

def parse_key_terms(key_terms_str):
    return ast.literal_eval(key_terms_str)

def load_image_data(csv_file_name):
    data = []
    with open(csv_file_name, mode='r', encoding='utf-8') as file:
        reader = csv.DictReader(file)
        for row in reader:
            key_terms = parse_key_terms(row['Keyterms'])
            row['Keyterms'] = preprocess_text(' '.join(key_terms))
            data.append(row)
    return data

def find_most_relevant_images(user_query, image_data, top_n=10):
    key_terms = extract_key_terms(user_query)
    corpus = [item['Keyterms'] for item in image_data]
    corpus.append(key_terms)
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(corpus)
    similarity_matrix = cosine_similarity(tfidf_matrix[:-1], tfidf_matrix[-1])
    top_indices = similarity_matrix.argsort(axis=None)[-top_n:][::-1]
    results = [(image_data[idx]['Class'], image_data[idx]['Path']) for idx in top_indices]
    return results

def load_questions(json_file):
    with open(json_file, 'r', encoding='utf-8') as file:
        questions = json.load(file)
    return questions

def solve_questions(questions, image_data, no_of_questions):
    score = 0
    total_questions = min(no_of_questions, len(questions))
    random.shuffle(questions)  
    for i, q in enumerate(questions[:no_of_questions], 1):
        print(f"\nQuestion {i}: {q['question']}")
        user_answer = q['answer'].lower()  
        top_results = find_most_relevant_images(q['question'], image_data)
        if top_results:
            top_class = top_results[0][0].lower().strip("'")  
            print(f"Retrieved class: {top_class}")
            if user_answer == top_class:
                print("Correct!")
                score += 1
            else:
                print(f"Incorrect. Correct class is: {user_answer}")
        else:
            print("No relevant images found.")
    print(f"\nYour score: {score}/{total_questions}")

csv_file_name = 'Image_Keyterms.csv'
json_file = 'questions.json'
image_data = load_image_data(csv_file_name)
questions = load_questions(json_file)
no_of_questions = 30
solve_questions(questions, image_data, no_of_questions)
# Out:
# Question 1: Identify the dance form from Kerala characterized by graceful movements and elaborate costumes?
# Retrieved class: kathakali
# Incorrect. Correct class is: mohiniyattam
#
# Question 2: What is the name of the painting style known for capturing the essence of a person on canvas?
# Retrieved class: portrait
# Correct!
#
# Question 3: Which art form is associated with Odisha, folk, and traditional painting?
# Retrieved class: pattachitra
# Correct!
#
# Question 4: Which religious site is associated with Sikh, Amritsar, and Punjab?
# Retrieved class: golden temple
# Correct!
#
# Question 5: Which monument in Delhi is known for architecture, unfinished, and history?
# Retrieved class: alai_minar
# Correct!
#
# Question 6: Which temple in Tamil Nadu is known for architecture, Chola, and UNESCO?
# Retrieved class: tanjavur temple
# Correct!
#
# Question 7: Which art form is associated with tribal, Maharashtra, and traditional painting?
# Retrieved class: warli
# Correct!
#
# ...

# %%
import csv
from nltk.corpus import wordnet

Keyterms = {
    'Tanjore': ['temple', 'art', 'culture', 'South India', 'painting'],
    'lotus_temple': ['architecture', 'delhi', 'bahai', 'worship', 'modern'],
    'manipuri': ['dance', 'northeast', 'manipur', 'traditional', 'culture'],
    'pattachitra': ['art', 'painting', 'odisha', 'folk', 'traditional'],
    'alai_minar': ['architecture', 'delhi', 'unfinished', 'monument', 'history'],
    'basilica_of_bom_jesus': ['church', 'goa', 'christianity', 'history', 'UNESCO'],
    'golden temple': ['sikh', 'amritsar', 'punjab', 'worship', 'architecture'],
    'Warli': ['art', 'tribal', 'maharashtra', 'painting', 'traditional'],
    'Kalamkari': ['art', 'textile', 'andhra pradesh', 'painting', 'traditional'],
    'Portrait': ['art', 'painting', 'portrait', 'canvas', 'artist'],
    'Khajuraho': ['temple', 'erotic', 'madhya pradesh', 'sculpture', 'architecture'],
    'bharatanatyam': ['dance', 'classical', 'Tamil Nadu', 'performance', 'tradition'],
    'hawa mahal pics': ['architecture', 'jaipur', 'rajasthan', 'pink city', 'palace'],
    'test': ['test', 'data', 'sample', 'experiment', 'analysis'],
    'Gateway of India': ['monument', 'mumbai', 'gateway', 'architecture', 'history'],
    'Fatehpur Sikri': ['fort', 'agra', 'mughal', 'architecture', 'unesco'],
    'kathakali': ['dance', 'kerala', 'classical', 'performance', 'tradition'],
    'Madhubani': ['art', 'painting', 'bihar', 'folk', 'traditional'],
    'kuchipudi': ['dance', 'andhra pradesh', 'classical', 'performance', 'tradition'],
    'Sun Temple Konark': ['temple', 'odisha', 'sun god', 'sculpture', 'architecture'],
    'iron_pillar': ['pillar', 'delhi', 'qutub minar', 'iron', 'history'],
    'alai_darwaza': ['architecture', 'delhi', 'monument', 'gateway', 'mughal'],
    'Chhota_Imambara': ['mosque', 'lucknow', 'nawab', 'architecture', 'history'],
    'charminar': ['mosque', 'hyderabad', 'monument', 'architecture', 'landmark'],
    'Kangra': ['fort', 'himachal pradesh', 'kangra valley', 'history', 'architecture'],
    'Hawa mahal': ['architecture', 'jaipur', 'rajasthan', 'pink city', 'palace'],
    'Ellora Caves': ['cave', 'maharashtra', 'unesco', 'sculpture', 'architecture'],
    'tanjavur temple': ['temple', 'tamil nadu', 'architecture', 'chola', 'unesco'],
    'Humayun_s Tomb': ['tomb', 'delhi', 'mughal', 'architecture', 'unesco'],
    'mysore_palace': ['palace', 'mysore', 'karnataka', 'architecture', 'royalty'],
    'India_gate': ['war memorial', 'delhi', 'architecture', 'india', 'history'],
    'odissi': ['dance', 'odisha', 'classical', 'performance', 'tradition'],
    'Charar-E- Sharif': ['mosque', 'kashmir', 'sufi', 'architecture', 'history'],
    'tajmahal': ['mausoleum', 'agra', 'mughal', 'architecture', 'unesco'],
    'victoria memorial': ['memorial', 'kolkata', 'architecture', 'history', 'british'],
    'sattriya': ['dance', 'assam', 'classical', 'performance', 'tradition'],
    'mohiniyattam': ['dance', 'kerala', 'classical', 'performance', 'tradition'],
    'Ajanta Caves': ['cave', 'maharashtra', 'unesco', 'sculpture', 'architecture'],
    'kathak': ['dance', 'uttar pradesh', 'classical', 'performance', 'tradition'],
    'Mural': ['art', 'painting', 'wall', 'mural', 'artist'],
    'qutub_minar': ['minaret', 'delhi', 'monument', 'history', 'architecture'],
    'India gate pics': ['war memorial', 'delhi', 'architecture', 'india', 'history'],
    'jamali_kamali_tomb': ['tomb', 'delhi', 'architecture', 'history', 'jamali kamali']
}

def get_wordnet_info(keyword):
    info = []
    synsets = wordnet.synsets(keyword)
    if synsets:
        for synset in synsets:
            # definition = synset.definition()
            # info.append(f"Definition: {definition}")
            examples = synset.examples()
            if examples:
                info.append(f"Examples: {', '.join(examples)}")
            synonyms = synset.lemma_names()
            if synonyms:
                info.append(f"Synonyms: {', '.join(synonyms)}")
            hypernyms = synset.hypernyms()
            if hypernyms:
                info.append(f"Hypernyms: {', '.join([h.lemmas()[0].name() for h in hypernyms])}")
            hyponyms = synset.hyponyms()
            if hyponyms:
                info.append(f"Hyponyms: {', '.join([h.lemmas()[0].name() for h in hyponyms])}")
    else:
        info.append("No information available in WordNet.")
    return "; ".join(info)

with open('WordNetData.csv', 'w', newline='') as csvfile:
    fieldnames = ['Class', 'Term', 'Data']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    for class_name, keywords in Keyterms.items():
        for term in keywords:
            data = get_wordnet_info(term)
            writer.writerow({'Class': class_name, 'Term': term, 'Data': data})
